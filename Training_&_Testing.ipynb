# %% [markdown]
# <a href="https://colab.research.google.com/github/tomyhrdnsyh/Analisis-Sentimen-Twitter-Vaksin-Covid-19/blob/main/Training_%26_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path = "/content/Tweet_Preprocessing.csv"
TWEET_DATA = pd.read_csv(path, usecols=["sentimen", "tweet_normalized"])
TWEET_DATA.columns = ["lable", "tweet"]
TWEET_DATA.lable = TWEET_DATA.lable.str.capitalize()
TWEET_DATA
# Out:
#        lable                                              tweet
# 0    Negatif  ['nikah', 'tahun', 'initapi', 'wna', 'boleh', ...
# 1    Positif     ['semangat', 'jokowimempertahankan', 'negara']
# 2    Negatif  ['jokowi', 'tolong', 'psbb', 'selesaikan', 'se...
# 3    Positif                                          ['sehat']
# 4    Negatif  ['bagaimana', 'mau', 'berjuang', 'suami', 'sud...
# ..       ...                                                ...
# 995  Negatif  ['sibuk', 'vaksinbiar', 'menkes', 'tugasnyaleb...
# 996  Positif       ['mudahan', 'tenaga', 'vaksin', 'jt', 'wni']
# 997  Positif  ['terima', 'kasih', 'bapak', 'presiden', 'sema...
# 998  Positif  ['kaltim', 'samarinda', 'hadir', 'salam', 'seh...
# 999  Positif                                         ['vaksin']
#
# [1000 rows x 2 columns]

# %% [markdown]
# # CONVERT STRING TO LIST

# %%
# convert list formated string to list
import ast

def convert_text_list(texts):
    texts = ast.literal_eval(texts)
    return [text for text in texts]

TWEET_DATA["tweet_list"] = TWEET_DATA["tweet"].apply(convert_text_list)
pd.DataFrame(TWEET_DATA[["tweet_list", "lable"]])
# Out:
#                                             tweet_list    lable
# 0    [nikah, tahun, initapi, wna, boleh, masuk, ind...  Negatif
# 1             [semangat, jokowimempertahankan, negara]  Positif
# 2    [jokowi, tolong, psbb, selesaikan, secepatnya,...  Negatif
# 3                                              [sehat]  Positif
# 4    [bagaimana, mau, berjuang, suami, sudah, kerja...  Negatif
# ..                                                 ...      ...
# 995  [sibuk, vaksinbiar, menkes, tugasnyalebih, vis...  Negatif
# 996                 [mudahan, tenaga, vaksin, jt, wni]  Positif
# 997       [terima, kasih, bapak, presiden, semangatya]  Positif
# 998  [kaltim, samarinda, hadir, salam, sehat, semog...  Positif
# 999                                           [vaksin]  Positif
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## Split Dataset

# %%
training_data = TWEET_DATA.sample(frac=0.8, random_state=50).reset_index()
training_data = training_data.drop(columns='index')
testing_data = TWEET_DATA.drop(training_data.index).reset_index()
testing_data = testing_data.drop(columns='index')

# %%
training_data
# Out:
#        lable  ...                                         tweet_list
# 0    Positif  ...           [jokowi, masuk, daftar, vaksin, ditahap]
# 1    Positif  ...                                       [sakit, itu]
# 2    Negatif  ...                                            [sakit]
# 3    Negatif  ...                           [bhineka, tinggal, duka]
# 4    Positif  ...                                      [terimakasih]
# ..       ...  ...                                                ...
# 795  Positif  ...  [tunggu, reaksi, vaksin, dari, bapak, berhasil...
# 796  Positif  ...                        [menghadapi, wabah, corona]
# 797  Positif  ...  [disiplin, patuh, protokol, kesehatan, insha, ...
# 798  Positif  ...  [mudah, mudahan, vaksin, halal, lupa, ikhtiar,...
# 799  Positif  ...  [semangat, papresku, semoga, sehat, walafiat, ...
#
# [800 rows x 3 columns]

# %%
testing_data
# Out:
#        lable  ...                                         tweet_list
# 0    Positif  ...                     [semangat, jokowi, presidenku]
# 1    Negatif  ...  [lapor, masyarakat, seperti, kasih, vaksin, se...
# 2    Positif  ...                                 [semangat, jokowi]
# 3    Negatif  ...  [jokowibln, februari, bansos, uang, tunai, bel...
# 4    Positif  ...  [semoga, indonesia, mengatasi, pandemi, allah,...
# ..       ...  ...                                                ...
# 195  Negatif  ...  [sibuk, vaksinbiar, menkes, tugasnyalebih, vis...
# 196  Positif  ...                 [mudahan, tenaga, vaksin, jt, wni]
# 197  Positif  ...       [terima, kasih, bapak, presiden, semangatya]
# 198  Positif  ...  [kaltim, samarinda, hadir, salam, sehat, semog...
# 199  Positif  ...                                           [vaksin]
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Split Pos Neg Dataset

# %%
training_data_pos = training_data[['lable', 'tweet_list']]
training_data_pos = training_data_pos[training_data_pos.lable == 'Positif'].reset_index()
training_data_pos = training_data_pos.drop(columns='index')
training_data_pos
# Out:
#        lable                                         tweet_list
# 0    Positif           [jokowi, masuk, daftar, vaksin, ditahap]
# 1    Positif                                       [sakit, itu]
# 2    Positif                                      [terimakasih]
# 3    Positif  [mantap, bapak, presidenkuslm, doa, tuhan, mah...
# 4    Positif  [assalamualaikumsmga, bapak, presiden, joko, w...
# ..       ...                                                ...
# 408  Positif  [tunggu, reaksi, vaksin, dari, bapak, berhasil...
# 409  Positif                        [menghadapi, wabah, corona]
# 410  Positif  [disiplin, patuh, protokol, kesehatan, insha, ...
# 411  Positif  [mudah, mudahan, vaksin, halal, lupa, ikhtiar,...
# 412  Positif  [semangat, papresku, semoga, sehat, walafiat, ...
#
# [413 rows x 2 columns]

# %%
training_data_neg = training_data[['lable', 'tweet_list']]
training_data_neg = training_data_neg[training_data_neg.lable == 'Negatif'].reset_index()
training_data_neg = training_data_neg.drop(columns='index')
training_data_neg
# Out:
#        lable                                         tweet_list
# 0    Negatif                                            [sakit]
# 1    Negatif                           [bhineka, tinggal, duka]
# 2    Negatif  [terhormat, bali, terpuruk, ekonominya, ppkm, ...
# 3    Negatif              [kampung, petani, sush, nyari, pupuk]
# 4    Negatif                               [aturan, bermanfaat]
# ..       ...                                                ...
# 382  Negatif                   [tipu, suntik, jarumnya, pendek]
# 383  Negatif                [cari, duit, susahrakyat, sengsara]
# 384  Negatif  [vaksin, psbb, berjalan, lapangan, pekerjaan, ...
# 385  Negatif  [perkenalkan, nama, putri, lestari, hambali, s...
# 386  Negatif                                          [sekolah]
#
# [387 rows x 2 columns]

# %% [markdown]
# **Menghitung Bobot TF**

# %%
def calc_TF(document):
    # Counts the number of times the word appears in review
    TF_dict = {}
    for term in document:
        if term in TF_dict:
            TF_dict[term] += 1
        else:
            TF_dict[term] = 1
    for term in TF_dict:
        TF_dict[term] = TF_dict[term] / len(document)
    return TF_dict

training_data_pos["TF_dict"] = training_data_pos['tweet_list'].apply(calc_TF)
training_data_neg["TF_dict"] = training_data_neg['tweet_list'].apply(calc_TF)
# training_data["TF_dict"] = training_data['tweet_list'].apply(calc_TF)
training_data_pos
# Out:
#        lable  ...                                            TF_dict
# 0    Positif  ...  {'jokowi': 0.2, 'masuk': 0.2, 'daftar': 0.2, '...
# 1    Positif  ...                         {'sakit': 0.5, 'itu': 0.5}
# 2    Positif  ...                               {'terimakasih': 1.0}
# 3    Positif  ...  {'mantap': 0.07692307692307693, 'bapak': 0.076...
# 4    Positif  ...  {'assalamualaikumsmga': 0.09090909090909091, '...
# ..       ...  ...                                                ...
# 408  Positif  ...  {'tunggu': 0.1111111111111111, 'reaksi': 0.111...
# 409  Positif  ...  {'menghadapi': 0.3333333333333333, 'wabah': 0....
# 410  Positif  ...  {'disiplin': 0.07142857142857142, 'patuh': 0.0...
# 411  Positif  ...  {'mudah': 0.1111111111111111, 'mudahan': 0.111...
# 412  Positif  ...  {'semangat': 0.14285714285714285, 'papresku': ...
#
# [413 rows x 3 columns]

# %%
def call_tf(query):
    call_tf = {}
    index = query.index
    for i in index:
        for term in query[i]:
            if term in call_tf:
                call_tf[term] += query[i][term]
            else:
                call_tf[term] = query[i][term]
    return call_tf

# %%
TF = call_tf(training_data["TF_dict"])
df_TF = pd.DataFrame(TF.items(), columns=["Istilah", "TF"])

TF_Pos = call_tf(training_data_pos["TF_dict"])
df_TF_Pos = pd.DataFrame(TF_Pos.items(), columns=["Istilah", "TF-Positif"])

TF_Neg = call_tf(training_data_neg["TF_dict"])
df_TF_Neg = pd.DataFrame(TF_Neg.items(), columns=["Istilah", "TF-Negatif"])

# %% [markdown]
# **Menghitung Bobot DF**

# %%
def calc_DF(tfDict):
    count_DF = {}
    # Run through each document's tf dictionary and increment countDict's (term, doc) pair
    for document in tfDict:
        for term in document:
            if term in count_DF:
                count_DF[term] += 1
            else:
                count_DF[term] = 1
    return count_DF

# %%
DF = calc_DF(training_data["TF_dict"])

# %%
df_DF = pd.DataFrame(DF.items(), columns=["Istilah", "DF"])
df_DF
# Out:
#          Istilah  DF
# 0          kabar   1
# 1           duka   1
# 2         dokter   1
# 3        pribadi   1
# 4           paus   1
# 5     fransiskus   1
# 6      meninggal   1
# 7         akibat   1
# 8          covid   2
# 9       vaksinya   1
# 10         halal   1
# 11           yaa   1
# 12        vaksin   4
# 13        buatan   1
# 14      tiongkok   1
# 15         orang   1
# 16           tua   1
# 17        suntik   1
# 18        nonton   1
# 19         video   1
# 20  selengkapnya   1
# 21         demam   1
# 22           lur   1
# 23     perbedaan   1
# 24         china   1
# 25       sinovac   1
# 26     sinopharm   1
# 27         merek   1
# 28          mari   1
# 29       siapkan   1
# 30     vaksinasi   1
# 31    laksanakan   1
# 32      protokol   1
# 33     kesehatan   1
# 34       memakai   1
# 35        masker   1
# 36          obat   1
# 37    selamatkan   1
# 38         nyawa   1
# 39        pasien   1
# 40     ditemukan   1
# 41         raffi   1
# 42         ahmad   1
# 43        girang   1
# 44      disuntik   1
# 45        ridwan   1
# 46         kamil   1
# 47         tegur   1
# 48       euforia   1

# %% [markdown]
# **Menghitung Bobot IDF**

# %%
def calc_IDF(__n_document, __DF):
    # print("Menghitung IDF\n")
    IDF_Dict = {}
    d = {}
    for term in __DF:
        IDF_Dict[term] = np.log10(__n_document / (__DF[term]))
    return IDF_Dict

# %%
# Stores the idf dictionary
n_document = len(training_data)
IDF = calc_IDF(n_document, DF)
IDF
# Out:
# {'jokowi': 0.978810700930062,
#  'masuk': 1.4559319556497243,
#  'daftar': 2.6020599913279625,
#  'vaksin': 0.9536999803470309,
#  'ditahap': 2.9030899869919438,
#  'sakit': 1.6726410656136697,
#  'itu': 2.3010299956639813,
#  'bhineka': 2.9030899869919438,
#  'tinggal': 2.1249387366083,
#  'duka': 2.9030899869919438,
#  'terimakasih': 1.8616973018337186,
#  'mantap': 1.5808706922580242,
#  'bapak': 1.3467874862246563,
#  'presidenkuslm': 2.9030899869919438,
#  'doa': 2.425968732272281,
#  'tuhan': 1.8239087409443189,
#  'maha': 2.6020599913279625,
#  'kuasa': 2.9030899869919438,
#  'melimpahi': 2.9030899869919438,
#  'anugerah': 2.9030899869919438,
#  'sehatkasih': 2.9030899869919438,
#  'sayangdan': 2.9030899869919438,
#  'berkat': 2.9030899869919438,
#  'perlindunganaim': 2.9030899869919438,
#  'assalamualaikumsmga': 2.9030899869919438,
#  'presiden': 0.9635707343733251,
#  'joko': 2.057991946977687,
#  'widodo': 2.1249387366083,
#  'keluarga': 1.9030899869919435,
#  'sehat': 0.8696662315049939,
#  'sllu': 2.6020599913279625,
#  'umuramin': 2.9030899869919438,
#  'yrb': 2.6020599913279625,
#  'terhormat': 2.0,
#  'bali': 2.425968732272281,
#  'terpuruk': 2.6020599913279625,
#  'ekonominya': 2.9030899869919438,
#  'ppkm': 2.425968732272281,
#  'taat': 2.6020599913279625,
#  'aturan': 2.204119982655925,
#  'lockdown': 1.8616973018337186,
#  'diperpanjang': 2.9030899869919438,
#  'kasihani': 2.9030899869919438,
#  'rakyatmu': 2.204119982655925,
#  'pedagang': 1.9030899869919435,
#  'berdagang': 2.6020599913279625,
#  'hasilkan': 2.9030899869919438,
#  'uang': 1.6243363860391147,
#  'sasarannya': 2.9030899869919438,
#  'kerumunan': 1.9030899869919435,
#  'pasar': 2.204119982655925,
#  'berkerumun': 2.6020599913279625,
#  'jam': 1.8239087409443189,
#  'pagi': 1.8616973018337186,
#  'basmi': 2.9030899869919438,
#  'pembatasan': 2.9030899869919438,
#  'malam': 1.8239087409443189,
#  'paklebih': 2.9030899869919438,
#  'atur': 2.9030899869919438,
#  'strategi': 2.9030899869919438,
#  'tolong': 1.3348882629249486,
#  'pulihkan': 2.6020599913279625,
#  'perekonomian': 2.3010299956639813,
#  'devisa': 2.9030899869919438,
#  'negara': 1.4406919890929875,
#  'bergantung': 2.9030899869919438,
#  'pariwisata': 2.425968732272281,
#  'menerus': 2.9030899869919438,
#  'mati': 1.6989700043360187,
#  'kelaparan': 1.9488474775526188,
#  'penyakitnya': 2.9030899869919438,
#  'dicarikan': 2.6020599913279625,
#  'solusi': 2.0,
#  'perekonomiannya': 2.9030899869919438,
#  'pulih': 2.425968732272281,
#  'butuh': 1.6478174818886375,
#  'makan': 1.5808706922580242,
#  'cicilan': 2.9030899869919438,
#  'sekolah': 1.411728293157671,
#  'bayar': 1.8616973018337186,
#  'kuliah': 2.9030899869919438,
#  'keringanan': 2.6020599913279625,
#  'menghasilkan': 2.9030899869919438,
#  'pandemi': 1.411728293157671,
#  'rakyat': 1.0579919469776868,
#  'presidenbahkan': 2.9030899869919438,
#  'semarang': 2.9030899869919438,
#  'psbb': 1.6478174818886375,
#  'psis': 2.9030899869919438,
#  'kampung': 2.425968732272281,
#  'petani': 2.6020599913279625,
#  'sush': 2.9030899869919438,
#  'nyari': 2.425968732272281,
#  'pupuk': 2.6020599913279625,
#  'bermanfaat': 2.3010299956639813,
#  'jaga': 1.8616973018337186,
#  'kesehatan': 1.411728293157671,
#  'stay': 2.6020599913279625,
#  'safe': 2.9030899869919438,
#  'pleaseeee': 2.9030899869919438,
#  'akui': 2.9030899869919438,
#  'berusaha': 2.9030899869919438,
#  'menyangkal': 2.9030899869919438,
#  'nomor': 2.0,
#  'pict': 2.9030899869919438,
#  'hoax': 2.425968732272281,
#  'semoga': 0.9892761346082268,
#  'bapa': 2.1249387366083,
#  'jag': 2.9030899869919438,
#  'allah': 1.6243363860391147,
#  "subhanahu wata'ala": 2.3010299956639813,
#  'indonesia': 1.083546051450075,
#  'tercinta': 2.3010299956639813,
#  'makmur': 2.6020599913279625,
#  'sllau': 2.9030899869919438,
#  'salalu': 2.6020599913279625,
#  'cepat': 1.5808706922580242,
#  'terlepas': 2.9030899869919438,
#  'covid': 0.9736710612776509,
#  'barakallahufik': 2.9030899869919438,
#  'pakdhe': 2.9030899869919438,
#  'kontol': 2.425968732272281,
#  'pa': 1.5606673061697374,
#  'semangat': 1.2798406965940432,
#  'sll': 2.3010299956639813,
#  'ngeh': 2.9030899869919438,
#  'masih': 2.204119982655925,
#  'byank': 2.9030899869919438,
#  'pr': 2.6020599913279625,
#  'harus': 2.204119982655925,
#  'diselesaikan': 2.9030899869919438,
#  'utang': 2.9030899869919438,
#  'sudah': 1.3590219426416679,
#  'ingin': 2.1249387366083,
#  'memberkati': 2.425968732272281,
#  'syiap': 2.9030899869919438,
#  'doakan': 2.6020599913279625,
#  'utamakan': 2.9030899869919438,
#  'panggil': 2.9030899869919438,
#  'gubernur': 2.9030899869919438,
#  'Jawa Tengah': 2.425968732272281,
#  'mohon': 1.5606673061697374,
#  'dikasih': 2.204119982655925,
#  'kebijaksanaan': 2.9030899869919438,
#  'dadakan': 2.9030899869919438,
#  'kemarin': 2.3010299956639813,
#  'berkembang': 2.9030899869919438,
#  'isu': 2.9030899869919438,
#  'desa': 2.204119982655925,
#  'harga': 2.3010299956639813,
#  'tempe': 2.9030899869919438,
#  'dari': 1.6726410656136697,
#  'orang': 1.1706962271689751,
#  'panik': 2.6020599913279625,
#  'berbondongbondong': 2.9030899869919438,
#  'insentif': 2.425968732272281,
#  'nakes': 1.9030899869919435,
#  'dipotong': 2.425968732272281,
#  'mending': 2.9030899869919438,
#  'cabut': 2.204119982655925,
#  'status': 2.6020599913279625,
#  'hebat': 2.425968732272281,
#  'program': 2.204119982655925,
#  'my': 2.9030899869919438,
#  'pemerintah': 1.5228787452803376,
#  'bagaimana': 1.6020599913279625,
#  'donk': 2.6020599913279625,
#  'wni': 2.425968732272281,
#  'ln': 2.6020599913279625,
#  'seandainya': 2.9030899869919438,
#  'usahakan': 2.9030899869919438,
#  'rakyatnya': 2.204119982655925,
#  'bravo': 2.9030899869919438,
#  'himbauan': 2.9030899869919438,
#  'kenyang': 2.9030899869919438,
#  'batalkan': 2.6020599913279625,
#  'miras': 1.9488474775526188,
#  'baikbaik': 2.9030899869919438,
#  'mengunci': 2.6020599913279625,
#  'negeri': 1.9030899869919435,
#  'larangan': 2.9030899869919438,
#  'rumah': 1.6020599913279625,
#  'kecuali': 2.9030899869919438,
#  'ketat': 2.204119982655925,
#  'april': 2.9030899869919438,
#  'menutup': 2.9030899869919438,
#  'toko': 2.425968732272281,
#  'pikir': 2.425968732272281,
#  'efektif': 2.204119982655925,
#  'ngarsa': 2.9030899869919438,
#  'dalem': 2.9030899869919438,
#  'sultanhamengkubuwonox': 2.9030899869919438,
#  'halal': 2.057991946977687,
#  'begitu': 2.1249387366083,
#  'tertawa': 2.9030899869919438,
#  'mari': 2.425968732272281,
#  'lawan': 2.6020599913279625,
#  'korona': 2.0,
#  'yuk': 2.9030899869919438,
#  'ramaikan': 2.9030899869919438,
#  'cegah': 2.9030899869919438,
#  'bodohin': 2.6020599913279625,
#  'bisnis': 2.3010299956639813,
#  'tenaga kerja Idonesia': 2.425968732272281,
#  'miskin': 2.204119982655925,
#  'ko': 2.1249387366083,
#  'beda': 2.9030899869919438,
#  'warga': 1.9488474775526188,
#  'bosen': 2.0,
#  'pelajar': 2.9030899869919438,
#  'jenuh': 2.6020599913279625,
#  'mandiri': 2.425968732272281,
#  'dipercepat': 2.425968732272281,
#  'sediakan': 2.9030899869919438,
#  'divaksin': 1.7891466346851068,
#  'al': 2.9030899869919438,
#  'hamdulilah': 2.9030899869919438,
#  'alloh': 2.6020599913279625,
#  'follow back': 2.9030899869919438,
#  'sukses': 2.0,
#  'keluarkan': 2.3010299956639813,
#  'perpu': 2.6020599913279625,
#  'ruu': 2.9030899869919438,
#  'cipta': 2.9030899869919438,
#  'kerja': 1.7891466346851068,
#  'lahh': 2.9030899869919438,
#  'pasal': 2.9030899869919438,
#  'aneh': 2.6020599913279625,
#  'periode': 2.9030899869919438,
#  'ceritain': 2.9030899869919438,
#  'teman': 2.3010299956639813,
#  'patuhilah': 2.9030899869919438,
#  'ppemimpin': 2.9030899869919438,
#  'ri': 1.8616973018337186,
#  'obat': 2.204119982655925,
#  'virus': 1.7569619513137056,
#  'corona': 1.5413621509743507,
#  'menghindari': 2.9030899869919438,
#  'akai': 2.9030899869919438,
#  'masker': 1.3348882629249486,
#  'jarak': 2.204119982655925,
#  'hindari': 2.9030899869919438,
#  'ingatlah': 2.9030899869919438,
#  'pakk': 2.057991946977687,
#  'wisatawan': 2.9030899869919438,
#  'terima': 1.7269987279362624,
#  'kasih': 1.4559319556497243,
#  'yesus': 2.6020599913279625,
#  'mengasihimu': 2.9030899869919438,
#  'pakde': 1.9488474775526188,
#  'kenapa': 1.9030899869919435,
#  'koruptor': 2.9030899869919438,
#  'dapet': 2.204119982655925,
#  'duluan': 2.9030899869919438,
#  'tahanan': 2.9030899869919438,
#  'masyarakat': 1.4881166390211256,
#  'belum': 1.8616973018337186,
#  'merugikan': 2.9030899869919438,
#  'jutaan': 2.6020599913279625,
#  'aturannya': 2.9030899869919438,
#  'diperjelas': 2.9030899869919438,
#  'Kementerian Kesehatan': 2.6020599913279625,
#  'bengkel': 2.9030899869919438,
#  'jalan': 1.6726410656136697,
#  'karyabakti': 2.6020599913279625,
#  'indrakasih': 2.6020599913279625,
#  'medan': 2.6020599913279625,
#  'beroperasi': 2.9030899869919438,
#  'mengancam': 2.9030899869919438,
#  'melempari': 2.9030899869919438,
#  'kamimpak': 2.9030899869919438,
#  'mandang': 2.9030899869919438,
#  'ntt': 2.9030899869919438,
#  'posting': 2.9030899869919438,
#  'lucu': 2.6020599913279625,
#  'ah': 2.425968732272281,
#  'de': 2.3010299956639813,
#  'mostingnya': 2.9030899869919438,
#  'geh': 2.9030899869919438,
#  'berdamai': 2.6020599913279625,
#  'cari': 2.0,
#  'sektor': 2.6020599913279625,
#  'karena': 1.6020599913279625,
#  'contoh': 2.3010299956639813,
#  'turkey': 2.9030899869919438,
#  'wna': 2.9030899869919438,
#  'bebas': 2.425968732272281,
#  'bertahan': 2.425968732272281,
#  'hidup': 1.7891466346851068,
#  'kaltim': 2.6020599913279625,
#  'samarinda': 2.9030899869919438,
#  'hadir': 2.6020599913279625,
#  'salam': 1.8239087409443189,
#  'lancar': 2.0,
#  'maju': 1.9488474775526188,
#  'selesai': 2.057991946977687,
#  'hallo': 2.9030899869919438,
#  'fans': 2.9030899869919438,
#  'sayang': 2.3010299956639813,
#  'love': 2.6020599913279625,
#  'kamu': 1.9488474775526188,
#  'tidak': 1.4717262228329564,
#  'dihargai': 2.9030899869919438,
#  'pemimpin': 2.6020599913279625,
#  'sukrano': 2.9030899869919438,
#  'dataang': 2.9030899869919438,
#  'kerjasama': 2.6020599913279625,
#  'bangsa': 1.9030899869919435,
#  'mashallah': 2.9030899869919438,
#  'tim': 2.9030899869919438,
#  'pro': 2.6020599913279625,
#  'kontra': 2.9030899869919438,
#  'apadaya': 2.9030899869919438,
#  'paham': 2.3010299956639813,
#  'tuk': 2.9030899869919438,
#  'dipercaya': 2.9030899869919438,
#  'berserah': 2.9030899869919438,
#  'sangkuasa': 2.9030899869919438,
#  'dibalik': 2.9030899869919438,
#  'kejadian': 2.425968732272281,
#  'mengeluarkan': 2.9030899869919438,
#  'komentar': 2.3010299956639813,
#  'menyakiti': 2.6020599913279625,
#  'hati': 2.3010299956639813,
#  'manusia': 2.1249387366083,
#  'melindungi': 2.425968732272281,
#  'menghakimi': 2.9030899869919438,
#  'mendoakan': 2.6020599913279625,
#  'membaik': 2.3010299956639813,
#  'sekolahgak': 2.9030899869919438,
#  'kaya': 1.9488474775526188,
#  'online': 2.1249387366083,
#  'malas': 2.9030899869919438,
#  'dirumah': 2.0,
#  'bosan': 2.425968732272281,
#  'pom': 2.9030899869919438,
#  'bensin': 2.9030899869919438,
#  'tutup': 1.7269987279362624,
#  'maksa': 2.3010299956639813,
#  'bencana': 2.425968732272281,
#  'parah': 2.6020599913279625,
#  'peringatan': 2.9030899869919438,
#  'parahnya': 2.6020599913279625,
#  'israel': 2.9030899869919438,
#  'pilihan': 2.6020599913279625,
#  'pilih': 2.3010299956639813,
#  'wibawa': 2.9030899869919438,
#  'kelihatan': 2.9030899869919438,
#  'berharga': 2.9030899869919438,
#  'aktif': 2.425968732272281,
#  'kembaliemak': 2.9030899869919438,
#  'jualaannnnnnn': 2.9030899869919438,
#  'bangkit': 2.425968732272281,
#  'dii': 2.9030899869919438,
#  'memikirkan': 2.3010299956639813,
#  'insya': 2.6020599913279625,
#  'sesuai': 2.425968732272281,
#  'tentukan': 2.9030899869919438,
#  'aamiin': 1.7891466346851068,
#  'chinabapak': 2.9030899869919438,
#  'aman': 2.1249387366083,
#  'mall': 2.204119982655925,
#  'buka': 1.9488474775526188,
#  'kaki': 2.425968732272281,
#  'obrak': 2.9030899869919438,
#  'perbolehkan': 2.9030899869919438,
#  'budaya': 2.9030899869919438,
#  'selamat': 1.9488474775526188,
#  'berjuang': 2.1249387366083,
#  'dengan': 2.3010299956639813,
#  'diharapkan': 2.9030899869919438,
#  'vaksinasi': 1.7269987279362624,
#  'berakhirx': 2.9030899869919438,
#  'jokowipresiden': 2.9030899869919438,
#  'kebanggaan': 2.6020599913279625,
#  'pakkk': 2.9030899869919438,
#  'amin': 1.9488474775526188,
#  'mudah': 2.6020599913279625,
#  'mudahan': 2.204119982655925,
#  'berjalan': 2.057991946977687,
#  'penuh': 2.3010299956639813,
#  'keberkahan': 2.9030899869919438,
#  'bagus': 2.204119982655925,
#  'mk': 2.9030899869919438,
#  'klontong': 2.9030899869919438,
#  'warung': 2.9030899869919438,
#  'kau': 2.425968732272281,
#  'memberi': 2.3010299956639813,
#  'kompensasi': 2.6020599913279625,
#  'ditutup': 2.425968732272281,
#  'paktutup': 2.9030899869919438,
#  'asing': 2.9030899869919438,
#  'warganya': 2.425968732272281,
#  'kena': 1.7269987279362624,
#  'enakn': 2.9030899869919438,
#  'juga': 1.6243363860391147,
#  'msukluar': 2.9030899869919438,
#  'lebay': 2.6020599913279625,
#  'disiplin': 2.3010299956639813,
#  'kepala': 2.9030899869919438,
#  'daerah': 1.9030899869919435,
#  'aparat': 2.3010299956639813,
#  'penegak': 2.9030899869919438,
#  'hukum': 2.204119982655925,
#  'dilapangan': 2.9030899869919438,
#  'tegur': 2.9030899869919438,
#  'tindak': 2.6020599913279625,
#  'membandel': 2.9030899869919438,
#  'pensiunkasian': 2.9030899869919438,
#  'berkrja': 2.9030899869919438,
#  'tetap': 2.1249387366083,
#  'pandang': 2.6020599913279625,
#  'sebelah': 2.9030899869919438,
#  'mata': 2.1249387366083,
#  'bangga': 2.204119982655925,
#  'kagum': 2.6020599913279625,
#  'memilih': 2.3010299956639813,
#  'sia': 2.6020599913279625,
#  'ibadah': 2.9030899869919438,
#  'wajib': 2.1249387366083,
#  'bekal': 2.9030899869919438,
#  'akhirat': 2.9030899869919438,
#  'diterima': 2.9030899869919438,
#  'selesaikan': 2.9030899869919438,
#  'secepatnya': 2.6020599913279625,
#  'pekerjaan': 2.204119982655925,
#  'gaji': 2.204119982655925,
#  'normal': 2.0,
#  'hutang': 2.9030899869919438,
#  'keperluan': 2.6020599913279625,
#  'jalankan': 2.9030899869919438,
#  'protokol': 1.6726410656136697,
#  'kesehatannya': 2.9030899869919438,
#  'sdgkan': 2.9030899869919438,
#  'blt': 2.204119982655925,
#  'prakerja': 2.1249387366083,
#  'cair': 2.425968732272281,
#  'sampai': 2.0,
#  'tenang': 2.3010299956639813,
#  'bohong': 2.057991946977687,
#  'hello': 2.9030899869919438,
#  'bp': 2.3010299956639813,
#  'bapakdi': 2.9030899869919438,
#  'berkahi': 2.9030899869919438,
#  'berakhirperekonomian': 2.9030899869919438,
#  'dilindungi': 2.9030899869919438,
#  'unur': 2.9030899869919438,
#  'lihat': 1.8616973018337186,
#  'seakan': 2.425968732272281,
#  'socdis': 2.9030899869919438,
#  'cuci': 2.425968732272281,
#  'tangan': 1.9030899869919435,
#  'longgar': 2.9030899869919438,
#  'kontrol': 2.9030899869919438,
#  'and': 2.6020599913279625,
#  'monitoring': 2.9030899869919438,
#  'kunci': 2.9030899869919438,
#  'guruminum': 2.9030899869919438,
#  'air': 2.425968732272281,
#  'bernafaskarna': 2.9030899869919438,
#  'udara': 2.425968732272281,
#  'kotor': 2.9030899869919438,
#  'kehirup': 2.9030899869919438,
#  'lagijadi': 2.9030899869919438,
#  'penyakittapi': 2.9030899869919438,
#  'pakai': 1.4717262228329564,
#  'ajhbukan': 2.9030899869919438,
#  'penyakit': 1.7891466346851068,
#  'tanda': 2.9030899869919438,
#  'kamiyg': 2.9030899869919438,
#  'tes': 2.3010299956639813,
#  'rapit': 2.9030899869919438,
#  'mahal': 2.3010299956639813,
#  'ribu': 2.6020599913279625,
#  'bayangin': 2.6020599913279625,
#  'susah': 1.6726410656136697,
#  'nurutin': 2.9030899869919438,
#  'peraturan': 2.204119982655925,
#  'seperti': 1.9488474775526188,
#  'begini': 2.057991946977687,
#  'oknum': 2.6020599913279625,
#  'mengambil': 2.6020599913279625,
#  'kesempatan': 2.425968732272281,
#  'ujung': 2.6020599913279625,
#  'nama': 2.425968732272281,
#  'emak': 2.9030899869919438,
#  'terdaftar': 2.9030899869919438,
#  'bantuan': 1.6726410656136697,
#  'sosial': 2.425968732272281,
#  'trimakasih': 2.425968732272281,
#  'presidenku': 1.9030899869919435,
#  'halo': 2.425968732272281,
#  'bngt': 2.9030899869919438,
#  'perjuangan': 2.6020599913279625,
#  'pengorbanan': 2.9030899869919438,
#  'berterimakasih': 2.9030899869919438,
#  'banget': 1.8616973018337186,
#  'udahin': 2.9030899869919438,
#  'ppkmpsbbnya': 2.9030899869919438,
#  'massal': 2.425968732272281,
#  'industri': 2.9030899869919438,
#  'perhotelan': 2.9030899869919438,
#  'colek': 2.9030899869919438,
#  'usul': 2.9030899869919438,
#  'suntik': 1.7269987279362624,
#  'ditargetkan': 2.9030899869919438,
#  'persen': 2.9030899869919438,
#  'memenuhi': 2.9030899869919438,
#  'terkena': 2.057991946977687,
#  'target': 2.9030899869919438,
#  'ofline': 2.6020599913279625,
#  'korupsi': 2.3010299956639813,
#  'membunuh': 2.9030899869919438,
#  'disuntik': 2.204119982655925,
#  'saya': 1.4881166390211256,
#  'mh': 2.9030899869919438,
#  'tauu': 2.9030899869919438,
#  'permainan': 2.425968732272281,
#  'elite': 2.9030899869919438,
#  'global': 2.9030899869919438,
#  'bsu': 2.425968732272281,
#  'bpjs': 2.204119982655925,
#  'ketenagakerjaan': 2.3010299956639813,
#  'lanjutkan': 2.6020599913279625,
#  'minimal': 2.6020599913279625,
#  'paaaakkkkkkkkkkkkkkkkk': 2.9030899869919438,
#  'semangatya': 2.9030899869919438,
#  'kedaluwarsa': 2.9030899869919438,
#  'sedih': 2.204119982655925,
#  'bnget': 2.9030899869919438,
#  'nasib': 2.1249387366083,
#  'dagang': 2.425968732272281,
#  'abon': 2.9030899869919438,
#  'dijamanny': 2.9030899869919438,
#  'bgini': 2.6020599913279625,
#  'bngettolong': 2.9030899869919438,
#  'pesan': 2.425968732272281,
#  'ada': 2.6020599913279625,
#  'penghasilan': 2.425968732272281,
#  'aduh': 2.9030899869919438,
#  'dokter': 1.7891466346851068,
#  'kejang': 2.6020599913279625,
#  'atuh': 2.9030899869919438,
#  'berastelorminyak': 2.9030899869919438,
#  'menurutku': 2.6020599913279625,
#  'faksin': 2.6020599913279625,
#  'nasi': 2.6020599913279625,
#  'protein': 2.9030899869919438,
#  'bergizi': 2.425968732272281,
#  'vaksinlebih': 2.9030899869919438,
#  'utama': 2.9030899869919438,
#  'bantuanya': 2.9030899869919438,
#  'terhindar': 2.9030899869919438,
#  'covidaamiin': 2.9030899869919438,
#  'keluhan': 2.425968732272281,
#  'karyawankudiskurang': 2.9030899869919438,
#  'asmaasal': 2.9030899869919438,
#  'mengisi': 2.9030899869919438,
#  'absen': 2.9030899869919438,
#  'tbctidak': 2.9030899869919438,
#  'computer': 2.9030899869919438,
#  'asam': 2.3010299956639813,
#  'uratasal': 2.9030899869919438,
#  'kantor': 2.425968732272281,
#  'uring': 2.9030899869919438,
#  'uringan': 2.9030899869919438,
#  'tidur': 2.425968732272281,
#  'ginjalgaji': 2.9030899869919438,
#  'kerjanya': 2.9030899869919438,
#  'lamban': 2.9030899869919438,
#  'pucatpulang': 2.9030899869919438,
#  'sekedar': 2.6020599913279625,
#  'tips': 2.9030899869919438,
#  'karyawan': 2.3010299956639813,
#  'mestinya': 2.6020599913279625,
#  'menghargai': 2.6020599913279625,
#  'swmua': 2.9030899869919438,
#  'berkomentar': 2.425968732272281,
#  'sederhana': 2.9030899869919438,
#  'tidaknperlu': 2.9030899869919438,
#  'matinya': 2.6020599913279625,
#  'mahluk': 2.9030899869919438,
#  'tapi': 2.3010299956639813,
#  'takdir': 2.9030899869919438,
#  'ketetapan': 2.9030899869919438,
#  'mencabut': 2.9030899869919438,
#  'nyawa': 2.425968732272281,
#  'takut': 1.7569619513137056,
#  'maksiat': 2.9030899869919438,
#  'dimana': 2.204119982655925,
#  'teguran': 2.9030899869919438,
#  'insyaf': 2.9030899869919438,
#  'ucapan': 2.9030899869919438,
#  'menyakitkan': 2.9030899869919438,
#  'perbuatan': 2.9030899869919438,
#  'setajam': 2.9030899869919438,
#  'serius': 2.6020599913279625,
#  'full': 2.9030899869919438,
#  'anak': 1.6478174818886375,
#  'susu': 2.9030899869919438,
#  'ala': 2.9030899869919438,
#  'kadarnya': 2.9030899869919438,
#  'gizi': 2.6020599913279625,
#  'makanan': 2.0,
#  'dimakan': 2.9030899869919438,
#  'tercukupi': 2.9030899869919438,
#  'memperkuat': 2.9030899869919438,
#  'daya': 2.425968732272281,
#  'tahan': 2.6020599913279625,
#  'tubuh': 2.057991946977687,
#  'melawan': 2.425968732272281,
#  'terpenuhi': 2.9030899869919438,
#  'berjualan': 2.425968732272281,
#  'beli': 1.9030899869919435,
#  'ayam': 2.6020599913279625,
#  'ikan': 2.6020599913279625,
#  'daging': 2.9030899869919438,
#  'buahan': 2.9030899869919438,
#  'pasan': 2.9030899869919438,
#  'pusing': 2.6020599913279625,
#  'memikirkannya': 2.9030899869919438,
#  'sipmantap': 2.9030899869919438,
#  'sedulurapa': 2.9030899869919438,
#  'lupamaskerokesemua': 2.9030899869919438,
#  'nihmau': 2.9030899869919438,
#  'bikinpizza': 2.9030899869919438,
#  'gorengmau': 2.9030899869919438,
#  'muka': 2.3010299956639813,
#  'sield': 2.9030899869919438,
#  'maskermodalnya': 2.9030899869919438,
#  'memberkahimu': 2.9030899869919438,
#  'sediain': 2.9030899869919438,
#  'versi': 2.6020599913279625,
#  'kapsul': 2.9030899869919438,
#  'suka': 2.0,
#  'setuju': 1.9488474775526188,
#  'taiwan': 2.6020599913279625,
#  'displin': 2.9030899869919438,
#  'mauingin': 2.9030899869919438,
#  'merasakan': 2.6020599913279625,
#  'santunan': 2.9030899869919438,
#  'bangetg': 2.9030899869919438,
#  'pencipta': 2.9030899869919438,
#  'banyaknya': 2.9030899869919438,
#  'selalu': 2.057991946977687,
#  'mengumbar': 2.9030899869919438,
#  'janji': 2.6020599913279625,
#  'sejaln': 2.9030899869919438,
#  'kenyataan': 2.9030899869919438,
#  'memohon': 2.9030899869919438,
#  'sang': 2.6020599913279625,
#  'mulut': 2.9030899869919438,
#  'pergi': 2.3010299956639813,
#  'kokkk': 2.9030899869919438,
#  'allhamdhulillah': 2.9030899869919438,
#  'assalamualaikum': 1.9488474775526188,
#  'lindungan': 2.204119982655925,
#  'esa': 2.6020599913279625,
#  'produktif': 2.9030899869919438,
#  'kreatif': 2.9030899869919438,
#  'dimasa': 2.425968732272281,
#  'bersuara': 2.9030899869919438,
#  'prihatin': 2.9030899869919438,
#  'sepak': 2.425968732272281,
#  'bola': 2.425968732272281,
#  'peringkat': 2.9030899869919438,
#  'fifa': 2.9030899869919438,
#  'tim nasional': 2.9030899869919438,
#  'turun': 2.425968732272281,
#  'liga': 2.9030899869919438,
#  'tetangga': 2.6020599913279625,
#  'liganya': 2.9030899869919438,
#  'suntikannya': 2.6020599913279625,
#  'tekan': 2.9030899869919438,
#  'tutupin': 2.9030899869919438,
#  'dokternya': 2.6020599913279625,
#  'yee': 2.9030899869919438,
#  'ragu': 2.425968732272281,
#  'yeeekeeen': 2.9030899869919438,
#  'guys': 2.9030899869919438,
#  'sholatiya': 2.9030899869919438,
#  'brsahabat': 2.9030899869919438,
#  'menyerang': 2.9030899869919438,
#  'paksin': 2.6020599913279625,
#  'ormis': 2.9030899869919438,
#  'jaket': 2.9030899869919438,
#  'maskeran': 2.6020599913279625,
#  'ngapain': 2.425968732272281,
#  'padamu': 2.9030899869919438,
#  'jelasin': 2.9030899869919438,
#  'hubungannya': 2.9030899869919438,
#  'anakanak': 2.9030899869919438,
#  'belajar': 2.3010299956639813,
#  'di sekolahan': 2.9030899869919438,
#  'patuhi': 2.425968732272281,
#  'lakukan': 2.9030899869919438,
#  'mwmakai': 2.9030899869919438,
#  'menjaga': 2.0,
#  'mencuci': 2.9030899869919438,
#  'laksanakan': 2.6020599913279625,
#  'tingkat': 2.6020599913279625,
#  'ksmbuhay': 2.9030899869919438,
#  'disini': 2.9030899869919438,
#  'bnyak': 2.1249387366083,
#  'knabahkan': 2.9030899869919438,
#  'lansiakomplikasiga': 2.9030899869919438,
#  'pas': 2.425968732272281,
#  'dinyatakan': 2.425968732272281,
#  'positif': 1.9488474775526188,
#  'smbhlbih': 2.9030899869919438,
#  'serem': 2.9030899869919438,
#  'jgt': 2.9030899869919438,
#  'tipes': 2.9030899869919438,
#  'daripada': 2.9030899869919438,
#  'semua': 2.3010299956639813,
#  'indah': 2.9030899869919438,
#  'direalisasikan': 2.9030899869919438,
#  'maaf': 1.7891466346851068,
#  'terkesan': 2.6020599913279625,
#  'idiot': 2.9030899869919438,
#  'lugu': 2.9030899869919438,
#  'tantangan': 2.9030899869919438,
#  'mukin': 2.9030899869919438,
#  'tidak mau': 2.9030899869919438,
#  'berubah': 2.9030899869919438,
#  'mudahhan': 2.9030899869919438,
#  'yra': 2.6020599913279625,
#  'msntap': 2.9030899869919438,
#  'diberlakukan': 2.3010299956639813,
#  'bablas': 2.6020599913279625,
#  'ditakutkan': 2.9030899869919438,
#  'angka': 2.057991946977687,
#  'meningkat': 2.425968732272281,
#  'sekolh': 2.9030899869919438,
#  'tetapi': 2.0,
#  'dapodik': 2.9030899869919438,
#  'biarkan': 2.6020599913279625,
#  'jarum': 2.204119982655925,
#  'melukai': 2.9030899869919438,
#  'kulit': 2.9030899869919438,
#  'keren': 2.6020599913279625,
#  'mu': 2.1249387366083,
#  'bener': 2.0,
#  'kl': 2.6020599913279625,
#  'tega': 2.9030899869919438,
#  'direncanakan': 2.9030899869919438,
#  'kasihan': 2.3010299956639813,
#  'komando': 2.9030899869919438,
#  'menteri': 2.204119982655925,
#  'penerangan': 2.9030899869919438,
#  'harmoko': 2.9030899869919438,
#  'siang': 2.425968732272281,
#  'sore': 2.425968732272281,
#  'menyiarkan': 2.6020599913279625,
#  'beres': 2.9030899869919438,
#  'gembar': 2.9030899869919438,
#  'gembor': 2.9030899869919438,
#  'rumasakit': 2.6020599913279625,
#  'pasien': 2.0,
#  'menyadari': 2.9030899869919438,
#  'hancur': 2.9030899869919438,
#  'tatanan': 2.9030899869919438,
#  'barunew': 2.9030899869919438,
#  'normalorde': 2.9030899869919438,
#  'kospirasi': 2.9030899869919438,
#  'pakbangun': 2.9030899869919438,
#  'membutuhkan': 2.6020599913279625,
#  'nekolim': 2.9030899869919438,
#  'neokolonialisme': 2.9030899869919438,
#  'imperialisme': 2.9030899869919438,
#  'soekarnois': 2.9030899869919438,
#  'mencegah': 2.425968732272281,
#  'mengatasi': 2.425968732272281,
#  'ketemu': 2.6020599913279625,
#  'mantappp': 2.9030899869919438,
#  'gi': 2.6020599913279625,
#  'kabarnya': 2.9030899869919438,
#  'harapan': 2.6020599913279625,
#  'ekonomi': 1.8239087409443189,
#  'ni': 2.9030899869919438,
#  'seumur': 2.6020599913279625,
#  'hidupbenar': 2.9030899869919438,
#  'nyata': 2.6020599913279625,
#  'perpanjang': 2.9030899869919438,
#  'jualan': 2.057991946977687,
#  'gimn': 2.9030899869919438,
#  'dapat': 1.8616973018337186,
#  'memakai': 2.1249387366083,
#  'madjer': 2.9030899869919438,
#  'bisa': 1.9488474775526188,
#  'terlindingi': 2.9030899869919438,
#  'pademi': 2.425968732272281,
#  'caronacovid': 2.9030899869919438,
#  'save': 2.9030899869919438,
#  'gaes': 2.9030899869919438,
#  'hadiah': 2.9030899869919438,
#  'tersayang': 2.9030899869919438,
#  'percayain': 2.9030899869919438,
#  'ajaa': 2.9030899869919438,
#  'cuma': 2.3010299956639813,
#  'kampus': 2.9030899869919438,
#  'sekolahan': 2.9030899869919438,
#  'sama': 2.1249387366083,
#  'sekolahana': 2.9030899869919438,
#  'libur': 2.425968732272281,
#  'haha': 2.425968732272281,
#  'nanti': 2.9030899869919438,
#  'titan': 2.9030899869919438,
#  'bertambah': 2.3010299956639813,
#  'cucu': 2.9030899869919438,
#  'trima': 2.3010299956639813,
#  'tenaga': 2.0,
#  'pejuang': 2.9030899869919438,
#  'terdepan': 2.9030899869919438,
#  'kayanya': 2.6020599913279625,
#  'memiliki': 2.9030899869919438,
#  'memperhatikan': 2.425968732272281,
#  'bagusnya': 2.9030899869919438,
#  'klau': 2.9030899869919438,
#  'apalg': 2.9030899869919438,
#  'zona': 2.425968732272281,
#  'hijau': 2.6020599913279625,
#  'alangkah': 2.9030899869919438,
#  'diobati': 2.9030899869919438,
#  'vokus': 2.9030899869919438,
#  'ke daerah': 2.9030899869919438,
#  'dilanda': 2.9030899869919438,
#  'saja': 2.057991946977687,
#  'izin': 1.9030899869919435,
#  'mengemukakan': 2.9030899869919438,
#  'pendapat': 2.3010299956639813,
#  'beranggapan': 2.9030899869919438,
#  'diganti': 2.3010299956639813,
#  'rapidswab': 2.9030899869919438,
#  'antigen': 2.6020599913279625,
#  'gratis': 1.9030899869919435,
#  'terarah': 2.9030899869919438,
#  'pencairan': 2.9030899869919438,
#  'anggaran': 2.3010299956639813,
#  'sejujurnya': 2.9030899869919438,
#  'sepenuhnya': 2.9030899869919438,
#  'tersedia': 2.9030899869919438,
#  'membebaskan': 2.9030899869919438,
#  'penerbit': 2.9030899869919438,
#  'usa': 2.9030899869919438,
#  'mewajibkan': 2.9030899869919438,
#  'sabar': 2.425968732272281,
#  'ku': 2.0,
#  'menyertai': 2.6020599913279625,
#  'persulit': 2.6020599913279625,
#  'hak': 2.6020599913279625,
#  'pt': 2.9030899869919438,
#  'bangkrut': 2.425968732272281,
#  'risegn': 2.9030899869919438,
#  'kadang': 2.425968732272281,
#  'surat': 2.425968732272281,
#  'terus': 1.9488474775526188,
#  'padhl': 2.9030899869919438,
#  'menengah': 2.6020599913279625,
#  'ktp': 2.6020599913279625,
#  'dki': 2.6020599913279625,
#  'jakarta': 2.3010299956639813,
#  'merantau': 2.9030899869919438,
#  'vaksinnya': 2.1249387366083,
#  'tolol': 2.9030899869919438,
#  'sip': 2.9030899869919438,
#  'dksih': 2.9030899869919438,
#  'kabar': 2.9030899869919438,
#  'lambung': 2.425968732272281,
#  'karantina': 2.9030899869919438,
#  'swab': 2.057991946977687,
#  'swabnya': 2.9030899869919438,
#  'hasil': 2.204119982655925,
#  'rahasiakan': 2.9030899869919438,
#  'pulang': 2.3010299956639813,
#  'rapid': 2.425968732272281,
#  'negatif': 2.425968732272281,
#  'maksudnya': 2.9030899869919438,
#  'dana': 2.057991946977687,
#  'rs': 2.3010299956639813,
#  'ditertibkan': 2.9030899869919438,
#  'perhatian': 2.6020599913279625,
#  'pelayanan': 2.9030899869919438,
#  'disalahkan': 2.9030899869919438,
#  'olahraga': 2.6020599913279625,
#  'khusus': 2.425968732272281,
#  'realisasi': 2.9030899869919438,
#  'satunya': 2.6020599913279625,
#  'hiburan': 2.425968732272281,
#  'prestasi': 2.9030899869919438,
#  'bukanya': 2.9030899869919438,
#  'stop': 2.6020599913279625,
#  'assalamualikum': 2.9030899869919438,
#  'wacanany': 2.9030899869919438,
#  'lengkap': 2.9030899869919438,
#  'transportasi': 2.6020599913279625,
#  'test': 2.6020599913279625,
#  'berlaku': 2.425968732272281,
#  'tumpul': 2.6020599913279625,
#  'keatas': 2.425968732272281,
#  'tajam': 2.9030899869919438,
#  'kebawah': 2.6020599913279625,
#  'foto': 2.9030899869919438,
#  'terpilih': 2.9030899869919438,
#  'dimuat': 2.9030899869919438,
#  'akun': 2.9030899869919438,
#  'anjaycepat': 2.9030899869919438,
#  'woyy': 2.9030899869919438,
#  'min': 2.6020599913279625,
#  'gosip': 2.9030899869919438,
#  'grandma': 2.9030899869919438,
#  'liz': 2.9030899869919438,
#  'muncul': 2.9030899869919438,
#  'fitnah': 2.9030899869919438,
#  'bahan': 2.6020599913279625,
#  'percobaan': 2.3010299956639813,
#  'jenis': 2.6020599913279625,
#  'mosok': 2.9030899869919438,
#  'curiga': 2.6020599913279625,
#  'lho': 2.9030899869919438,
#  'wkwkwkwk': 2.9030899869919438,
#  'lampis': 2.9030899869919438,
#  'sesak': 2.6020599913279625,
#  'nafas': 2.6020599913279625,
#  'terhormatmembaca': 2.9030899869919438,
#  'ulang': 2.3010299956639813,
#  'inicoba': 2.9030899869919438,
#  'situasi': 2.6020599913279625,
#  'iniapakah': 2.9030899869919438,
#  'melihatato': 2.9030899869919438,
#  'mendengar': 2.9030899869919438,
#  'beritanyasy': 2.9030899869919438,
#  'pasti': 2.9030899869919438,
#  'tausetau': 2.9030899869919438,
#  'menindak': 2.6020599913279625,
#  'mematuhi': 2.3010299956639813,
#  'kanterbukti': 2.9030899869919438,
#  'banyak': 2.425968732272281,
#  'disuruh': 2.3010299956639813,
#  'bersihin': 2.9030899869919438,
#  'nyapu': 2.9030899869919438,
#  'jadi': 2.9030899869919438,
#  'nowapa': 2.9030899869919438,
#  'bapakitu': 2.9030899869919438,
#  'kadarluarsa': 2.9030899869919438,
#  'bagaimanakrn': 2.9030899869919438,
#  'lebih': 2.425968732272281,
#  'kansekian': 2.9030899869919438,
#  'suara': 2.6020599913279625,
#  'didenda': 2.9030899869919438,
#  'digresik': 2.9030899869919438,
#  'mndapatkan': 2.9030899869919438,
#  'suntikan': 2.204119982655925,
#  'sipil': 2.9030899869919438,
#  'jadikan': 2.9030899869919438,
#  'pil': 2.9030899869919438,
#  'minum': 2.425968732272281,
#  'walafiat': 2.6020599913279625,
#  'sekeluarga': 2.9030899869919438,
#  'era': 2.9030899869919438,
#  'reformasi': 2.6020599913279625,
#  'depannya': 2.9030899869919438,
#  'dtentukan': 2.9030899869919438,
#  'hanya': 2.6020599913279625,
#  'kampanye': 2.6020599913279625,
#  'capres': 2.9030899869919438,
#  'lagi': 2.057991946977687,
#  'gbhn': 2.9030899869919438,
#  'dtetapkn': 2.9030899869919438,
#  'mpr': 2.6020599913279625,
#  'jika': 2.9030899869919438,
#  'trpilih': 2.9030899869919438,
#  'adlh': 2.9030899869919438,
#  'hobi': 2.9030899869919438,
#  'berkhayal': 2.6020599913279625,
#  'mbiarkan': 2.9030899869919438,
#  'mrajalela': 2.9030899869919438,
#  'prsoalan': 2.9030899869919438,
#  'ucapannya': 2.9030899869919438,
#  'sendiri': 2.9030899869919438,
#  'paakk': 2.9030899869919438,
#  'jokowii': 2.9030899869919438,
#  'rsud': 2.9030899869919438,
#  'dipersiapkan': 2.9030899869919438,
#  'penurunan': 2.9030899869919438,
#  'wabah': 2.425968732272281,
#  'apd': 2.9030899869919438,
#  'dimaksimalkan': 2.9030899869919438,
#  'gugur': 2.9030899869919438,
#  'berikhtiar': 2.9030899869919438,
#  'sekuat': 2.9030899869919438,
#  'ruang': 2.9030899869919438,
#  'operasi': 2.9030899869919438,
#  'icu': 2.9030899869919438,
#  'kamar': 2.9030899869919438,
#  'nicu': 2.9030899869919438,
#  'bayi': 2.9030899869919438,
#  'rosulullah': 2.9030899869919438,
#  'bogor': 2.204119982655925,
#  'kacau': 2.6020599913279625,
#  ...}

# %%
def rumus_IDF(__n_document, __DF):
    IDF_Dict = {}
    d = {}
    df = {}
    rumus = {}
    for term in __DF:
        IDF_Dict[term] = np.log10(__n_document / (__DF[term]))
        d[term] = __n_document
        df[term] = __DF[term]
        rumus[term] = 'log({}/{})'.format(round(d[term], 6), round(df[term], 4)) 
    IDF_Dict = pd.DataFrame({ 'D':pd.Series(d), 'DF':pd.Series(df), 'Rumus IDF = log(D/DF)':pd.Series(rumus), 'IDF':pd.Series(IDF_Dict)}).reset_index()
    return IDF_Dict

# %%
df_IDF = rumus_IDF(n_document, DF)
df_IDF = df_IDF.rename(columns={'index': 'Istilah'})
df_IDF
# Out:
#        Istilah    D  DF Rumus IDF = log(D/DF)       IDF
# 0       jokowi  800  84           log(800/84)  0.978811
# 1        masuk  800  28           log(800/28)  1.455932
# 2       daftar  800   2            log(800/2)  2.602060
# 3       vaksin  800  89           log(800/89)  0.953700
# 4      ditahap  800   1            log(800/1)  2.903090
# ...        ...  ...  ..                   ...       ...
# 3086   alamiin  800   1            log(800/1)  2.903090
# 3087   ikhtiar  800   1            log(800/1)  2.903090
# 3088  mendekat  800   1            log(800/1)  2.903090
# 3089    khalik  800   1            log(800/1)  2.903090
# 3090  papresku  800   1            log(800/1)  2.903090
#
# [3091 rows x 5 columns]

# %%
print('Total IDF = ', df_IDF['IDF'].sum())
# Out:
# Total IDF =  8510.16355844541

# %% [markdown]
# **Menghitung Bobot TFIDF**

# %%
#calc TF-IDF
def calc_TF_IDF(TF):
    TF_IDF_Dict = {}
    #For each word in the review, we multiply its tf and its idf.
    for key in TF:
        TF_IDF_Dict[key] = TF[key] * IDF[key]
    return TF_IDF_Dict

# %% [markdown]
# TFIDF secara keseluruhan

# %%
# TF-IDF secara keseluruhan
training_data["TF-IDF_dict"] = training_data["TF_dict"].apply(calc_TF_IDF)
training_data
# Out:
#      lable  ...                                        TF-IDF_dict
# 0  Positif  ...  {'kabar': 0.10034333188799371, 'duka': 0.10034...
# 1  Positif  ...  {'vaksinya': 0.30102999566398114, 'halal': 0.3...
# 2  Positif  ...  {'vaksin': 0.03344777729599791, 'buatan': 0.10...
# 3  Negatif  ...  {'demam': 0.45154499349597177, 'lur': 0.451544...
# 4  Positif  ...  {'perbedaan': 0.15051499783199057, 'vaksin': 0...
# 5  Positif  ...  {'mari': 0.10034333188799371, 'siapkan': 0.100...
# 6  Positif  ...  {'obat': 0.15051499783199057, 'selamatkan': 0....
# 7  Negatif  ...  {'raffi': 0.10034333188799371, 'ahmad': 0.1003...
#
# [8 rows x 5 columns]

# %%
training_data_pos["TF-IDF_dict"] = training_data_pos["TF_dict"].apply(calc_TF_IDF)
training_data_pos
# Out:
#        lable  ...                                        TF-IDF_dict
# 0    Positif  ...  {'jokowi': 0.1957621401860124, 'masuk': 0.2911...
# 1    Positif  ...  {'sakit': 0.8363205328068348, 'itu': 1.1505149...
# 2    Positif  ...                {'terimakasih': 1.8616973018337186}
# 3    Positif  ...  {'mantap': 0.12160543786600186, 'bapak': 0.103...
# 4    Positif  ...  {'assalamualaikumsmga': 0.26391727154472217, '...
# ..       ...  ...                                                ...
# 408  Positif  ...  {'tunggu': 0.26955208136358677, 'reaksi': 0.32...
# 409  Positif  ...  {'menghadapi': 0.8673533304426542, 'wabah': 0....
# 410  Positif  ...  {'disiplin': 0.1643592854045701, 'patuh': 0.18...
# 411  Positif  ...  {'mudah': 0.289117776814218, 'mudahan': 0.2449...
# 412  Positif  ...  {'semangat': 0.18283438522772044, 'papresku': ...
#
# [413 rows x 4 columns]

# %%
training_data_neg["TF-IDF_dict"] = training_data_neg["TF_dict"].apply(calc_TF_IDF)
training_data_neg
# Out:
#        lable  ...                                        TF-IDF_dict
# 0    Negatif  ...                      {'sakit': 1.6726410656136697}
# 1    Negatif  ...  {'bhineka': 0.9676966623306479, 'tinggal': 0.7...
# 2    Negatif  ...  {'terhormat': 0.030303030303030304, 'bali': 0....
# 3    Negatif  ...  {'kampung': 0.48519374645445623, 'petani': 0.5...
# 4    Negatif  ...  {'aturan': 1.1020599913279625, 'bermanfaat': 1...
# ..       ...  ...                                                ...
# 382  Negatif  ...  {'tipu': 0.7257724967479859, 'suntik': 0.43174...
# 383  Negatif  ...  {'cari': 0.5, 'duit': 0.5510299956639813, 'sus...
# 384  Negatif  ...  {'vaksin': 0.012226922824961933, 'psbb': 0.042...
# 385  Negatif  ...  {'perkenalkan': 0.060513023054138665, 'nama': ...
# 386  Negatif  ...                     {'sekolah': 1.411728293157671}
#
# [387 rows x 4 columns]

# %% [markdown]
# # Fungsi Untuk Memanggil TF-IDF

# %%
def rumus_TF_IDF(__tf, __idf):
  __TF = {}
  __IDF =  {}
  rumus_TF_IDF = {}
  for key in __tf:
    __TF[key] = __tf[key]
    __IDF[key] = __idf[key]
    rumus_TF_IDF[key] = '{} * {}'.format(round(__tf[key], 6), round(__idf[key], 4)) 

  rumus_TF_IDF = pd.DataFrame({'TF':pd.Series(__TF), 'IDF':pd.Series(__IDF), 'Rumus':pd.Series(rumus_TF_IDF)}).reset_index()
  return rumus_TF_IDF

# %%
def fix_tf_idf(query):
    tf_idf_ = {}
    kemunculan = {}
    index = query.index
    for i in index:
        for term in query["TF-IDF_dict"][i]:
          if term in tf_idf_:
                tf_idf_[term] += query["TF-IDF_dict"][i][term]
                kemunculan[term] += 1
          else:
                tf_idf_[term] = query["TF-IDF_dict"][i][term]
                kemunculan[term] = 1
    tf_idf_ = pd.DataFrame({'Kemunculan':pd.Series(kemunculan), 'TF-IDF':pd.Series(tf_idf_)}).reset_index()
    return tf_idf_

# %% [markdown]
# # FULL TFIDF

# %%
fix_tfidf_full = fix_tf_idf(training_data)
fix_tfidf_full.columns = ['Istilah', 'Kemunculan', 'TF-IDF']
rumus = rumus_TF_IDF(TF, IDF)
fix_tfidf_full.insert(2, 'TF', rumus['TF'])
fix_tfidf_full.insert(3, 'IDF', rumus['IDF'])
fix_tfidf_full.insert(4, 'TF-IDF=TF*IDF', rumus['Rumus'])
fix_tfidf_full
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TF-IDF_dict'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-4625f39184dd> in <module>()
# ----> 1 fix_tfidf_full = fix_tf_idf(training_data)
#       2 fix_tfidf_full.columns = ['Istilah', 'Kemunculan', 'TF-IDF']
#       3 rumus = rumus_TF_IDF(TF, IDF)
#       4 fix_tfidf_full.insert(2, 'TF', rumus['TF'])
#       5 fix_tfidf_full.insert(3, 'IDF', rumus['IDF'])
#
# <ipython-input-36-da7953258b0a> in fix_tf_idf(query)
#       4     index = query.index
#       5     for i in index:
# ----> 6         for term in query["TF-IDF_dict"][i]:
#       7           if term in tf_idf_:
#       8                 tf_idf_[term] += query["TF-IDF_dict"][i][term]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'TF-IDF_dict'

# %% [markdown]
# ## TFIDF POSITIF

# %%
fix_tfidf_pos = fix_tf_idf(training_data_pos)
fix_tfidf_pos.columns = ['Istilah Positif', 'Kemunculan', 'TF-IDF']
rumus = rumus_TF_IDF(TF_Pos, IDF)
fix_tfidf_pos.insert(2, 'TF', rumus['TF'])
fix_tfidf_pos.insert(3, 'IDF', rumus['IDF'])
fix_tfidf_pos.insert(4, 'TF-IDF=TF*IDF', rumus['Rumus'])
fix_tfidf_pos
# Out:
#      Istilah Positif  Kemunculan  ...       TF-IDF=TF*IDF     TF-IDF
# 0             jokowi          60  ...  15.100185 * 0.9788  14.780223
# 1              masuk           9  ...   1.805357 * 1.4559   2.628477
# 2             daftar           1  ...        0.2 * 2.6021   0.520412
# 3             vaksin          47  ...  12.397893 * 0.9537  11.823871
# 4            ditahap           1  ...        0.2 * 2.9031   0.580618
# ...              ...         ...  ...                 ...        ...
# 1058         ikhtiar           1  ...   0.111111 * 2.9031   0.322566
# 1059        mendekat           1  ...   0.111111 * 2.9031   0.322566
# 1060            sang           1  ...   0.111111 * 2.6021   0.289118
# 1061          khalik           1  ...   0.111111 * 2.9031   0.322566
# 1062        papresku           1  ...   0.142857 * 2.9031   0.414727
#
# [1063 rows x 6 columns]

# %% [markdown]
# TFIDF NEGATIF

# %%
fix_tfidf_neg = fix_tf_idf(training_data_neg)
fix_tfidf_neg.columns = ['Istilah Negatif', 'Kemunculan', 'TF-IDF']
rumus = rumus_TF_IDF(TF_Neg, IDF)
fix_tfidf_neg.insert(2, 'TF', rumus['TF'])
fix_tfidf_neg.insert(3, 'IDF', rumus['IDF'])
fix_tfidf_neg.insert(4, 'TF-IDF=TF*IDF', rumus['Rumus'])

fix_tfidf_neg
# Out:
#      Istilah Negatif  Kemunculan  ...      TF-IDF=TF*IDF    TF-IDF
# 0              sakit          11  ...   1.67552 * 1.6726  2.802544
# 1            bhineka           1  ...  0.333333 * 2.9031  0.967697
# 2            tinggal           5  ...  0.668943 * 2.1249  1.421462
# 3               duka           1  ...  0.333333 * 2.9031  0.967697
# 4          terhormat           7  ...     0.472125 * 2.0  0.944250
# ...              ...         ...  ...                ...       ...
# 2425       kabupaten           1  ...  0.023256 * 2.6021  0.060513
# 2426     berkomentar           1  ...   0.023256 * 2.426  0.056418
# 2427       postingan           1  ...  0.023256 * 2.9031  0.067514
# 2428      terkenanya           1  ...  0.023256 * 2.9031  0.067514
# 2429         jaminan           1  ...  0.023256 * 2.9031  0.067514
#
# [2430 rows x 6 columns]

# %% [markdown]
# Menghitung Total TFIDF

# %%
print('Total TF-IDF Pos', fix_tfidf_pos['TF-IDF'].sum())
# Out:
# Total TF-IDF Pos 784.9308385990958

# %% [markdown]
# MENGHITUNG TFIDF NEGATIF

# %%
print('Total TF-IDF Neg', fix_tfidf_neg['TF-IDF'].sum())
# Out:
# Total TF-IDF Neg 861.9607794546077

# %% [markdown]
# TOTAL TFIDF POSITIF DAN NEGATIF

# %%
total_tfidf_full = fix_tfidf_pos['TF-IDF'].sum()+fix_tfidf_neg['TF-IDF'].sum()
print('Total TF-IDF Keseluruhan = ', total_tfidf_full)
# Out:
# Total TF-IDF Keseluruhan =  1646.8916180537035

# %% [markdown]
# # Testing Data

# %%
testing_data
# Out:
#        lable  ...                                         tweet_list
# 0    Positif  ...                     [semangat, jokowi, presidenku]
# 1    Negatif  ...  [lapor, masyarakat, seperti, kasih, vaksin, se...
# 2    Positif  ...                                 [semangat, jokowi]
# 3    Negatif  ...  [jokowibln, februari, bansos, uang, tunai, bel...
# 4    Positif  ...  [semoga, indonesia, mengatasi, pandemi, allah,...
# ..       ...  ...                                                ...
# 195  Negatif  ...  [sibuk, vaksinbiar, menkes, tugasnyalebih, vis...
# 196  Positif  ...                 [mudahan, tenaga, vaksin, jt, wni]
# 197  Positif  ...       [terima, kasih, bapak, presiden, semangatya]
# 198  Positif  ...  [kaltim, samarinda, hadir, salam, sehat, semog...
# 199  Positif  ...                                           [vaksin]
#
# [200 rows x 3 columns]

# %%
def calc_probability(uji, kelas, idf):
    calc_prob = {}
    for term in uji:
        if term in kelas.index:
          calc_prob[term] = (kelas['TF-IDF'][term]+1)/(kelas['TF-IDF'].sum()+idf['IDF'].sum())
        else:
          calc_prob[term] = (0+1)/(kelas['TF-IDF'].sum()+idf['IDF'].sum())
    return calc_prob

# %%
kelas_pos = fix_tfidf_pos.set_index('Istilah Positif')
kelas_neg = fix_tfidf_neg.set_index('Istilah Negatif')

# %%
testing_data['Cond Probability Positif'] = testing_data['tweet_list'].apply(calc_probability, kelas=(kelas_pos), idf=(df_IDF))
testing_data['Cond Probability Negatif'] = testing_data['tweet_list'].apply(calc_probability, kelas=(kelas_neg), idf=(df_IDF))
testing_data
# Out:
#        lable  ...                           Cond Probability Negatif
# 0    Positif  ...  {'semangat': 0.0001476083628143587, 'jokowi': ...
# 1    Negatif  ...  {'lapor': 0.00014011881165207807, 'masyarakat'...
# 2    Positif  ...  {'semangat': 0.0001476083628143587, 'jokowi': ...
# 3    Negatif  ...  {'jokowibln': 0.00013251255753836231, 'februar...
# 4    Positif  ...  {'semoga': 0.00019436075686825598, 'indonesia'...
# ..       ...  ...                                                ...
# 195  Negatif  ...  {'sibuk': 0.00023163659783284686, 'vaksinbiar'...
# 196  Positif  ...  {'mudahan': 0.00010669939535011192, 'tenaga': ...
# 197  Positif  ...  {'terima': 0.00012492308829515364, 'kasih': 0....
# 198  Positif  ...  {'kaltim': 0.0001414041738175383, 'samarinda':...
# 199  Positif  ...                  {'vaksin': 0.0007347271499300473}
#
# [200 rows x 5 columns]

# %%
def Posterior_Probability(conditional_prob, prior_probability):
    posterior_prob = 1
    for key in conditional_prob:
        posterior_prob = posterior_prob*conditional_prob[key]
    posterior_prob = posterior_prob*prior_probability
    return posterior_prob

# %%
total_train = len(training_data_pos)+len(training_data_neg)
prior_probability_pos = len(training_data_pos)/total_train
prior_probability_neg = len(training_data_neg)/total_train

testing_data['Post_Prob_Pos'] = testing_data['Cond Probability Positif'].apply(Posterior_Probability, prior_probability=(prior_probability_pos))
testing_data['Post_Prob_Neg'] = testing_data['Cond Probability Negatif'].apply(Posterior_Probability, prior_probability=(prior_probability_neg))

# %%
testing_data
# Out:
#        lable  ... Post_Prob_Neg
# 0    Positif  ...  2.429857e-12
# 1    Negatif  ...  6.589020e-34
# 2    Positif  ...  2.035217e-08
# 3    Negatif  ...  1.372629e-46
# 4    Positif  ...  2.495354e-23
# ..       ...  ...           ...
# 195  Negatif  ...  1.224943e-76
# 196  Positif  ...  9.921209e-20
# 197  Positif  ...  1.970171e-19
# 198  Positif  ...  5.533151e-28
# 199  Positif  ...  3.554243e-04
#
# [200 rows x 7 columns]

# %%
testing_data['Prediksi'] = np.where(testing_data['Post_Prob_Pos'] >= testing_data['Post_Prob_Neg'], 'Positif', 'Negatif')
testing_data.lable = testing_data.lable.str.capitalize()
testing_data
# Out:
#        lable  ... Prediksi
# 0    Positif  ...  Positif
# 1    Negatif  ...  Negatif
# 2    Positif  ...  Positif
# 3    Negatif  ...  Negatif
# 4    Positif  ...  Positif
# ..       ...  ...      ...
# 195  Negatif  ...  Negatif
# 196  Positif  ...  Positif
# 197  Positif  ...  Positif
# 198  Positif  ...  Positif
# 199  Positif  ...  Positif
#
# [200 rows x 8 columns]

# %%
testing_data['Kesesuaian'] = np.where(testing_data['Prediksi'] == testing_data['lable'], 'Sesuai', 'Tidak Sesuai')
testing_data
# Out:
#        lable  ... Kesesuaian
# 0    Positif  ...     Sesuai
# 1    Negatif  ...     Sesuai
# 2    Positif  ...     Sesuai
# 3    Negatif  ...     Sesuai
# 4    Positif  ...     Sesuai
# ..       ...  ...        ...
# 195  Negatif  ...     Sesuai
# 196  Positif  ...     Sesuai
# 197  Positif  ...     Sesuai
# 198  Positif  ...     Sesuai
# 199  Positif  ...     Sesuai
#
# [200 rows x 9 columns]

# %%
sesuai = len(testing_data[testing_data.Kesesuaian == 'Sesuai'])
total = len(testing_data)
akurasi = (sesuai/total)*100

# %%
print('Akurasi = {} %'.format(akurasi))
# Out:
# Akurasi = 92.5 %
